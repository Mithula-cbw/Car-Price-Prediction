# %% [markdown]
# # 04 – Modeling & Evaluation
# ### Car Price Prediction Using Machine Learning
# Group Assignment 02 - CCS3012 - Data Analytics
# Submission Date: 16th September 2025

# %% [markdown]
# ---
#
# ### **Group 11**
# -  **FC211034 - N.D. Samararathne Kodikara**
# -  **FC211013 - N.W.V. Tharindu Pabasara**
# -  **FC211025 - W.M.M.C.B. Wijesundara**
#
#
#
# ---

# %% [markdown]
# ### **Supervisor**
# **Ms. Dilmi Praveena**
# *Faculty of Computing*
# *University of Sri Jayewardenepura*
#
# ---

# %% [markdown]
# ## 📌 Objectives
#
# This notebook builds upon the cleaned dataset produced in **Notebook 01 — Data Exploration & Cleaning**.
# The focus here is to prepare the dataset for modeling by performing outlier handling, feature engineering, and deterministic cleaning.
#
# ---
#
# - Load processed train/test datasets and mappings from Notebook 02.
#
# - Prepare numeric and categorical pipelines.
#
# - Train and evaluate multiple regression models.
#
# - Compare performance metrics (RMSE, MAE, R²) to select the best model.
#
# - Save final model(s) for deployment or further analysis.
#
#
# ---

# %% [markdown]
# ### 📂 Input
# - `clean_data.csv` saved in `Data/processed/`
# - `X_train.pkl, X_test.pkl`
#
# - `y_train_log.pkl, y_test_log.pkl`
#
# - `y_train_cap.pkl, y_test_cap.pkl`
#
# - `categorical_mappings.pkl, model_mappings.pkl`
#
#
# ---

# %% [markdown]
# # imports

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import joblib
import pickle
import os

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Regression models
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Utility for saving
import joblib

# %% [markdown]
# # **Load Processed Data & Mappings**

# %% [markdown]
# ## Load Data

# %%
# Load processed datasets
X_train = joblib.load('Data/processed/X_train.pkl')
X_test = joblib.load('Data/processed/X_test.pkl')

 # For scale-sensitive models
y_train_log = joblib.load('Data/processed/y_train_log.pkl')
y_test_log = joblib.load('Data/processed/y_test_log.pkl')

 # For tree-based models
y_train_cap = joblib.load('Data/processed/y_train_cap.pkl')
y_test_cap = joblib.load('Data/processed/y_test_cap.pkl')

# %%
# Load mappings
with open('Data/processed/categorical_mappings.pkl', 'rb') as f:
    categorical_mappings = pickle.load(f)

with open('Data/processed/model_mappings.pkl', 'rb') as f:
    model_mappings = pickle.load(f)

# %% [markdown]
# ## Quick inspection

# %%
# Quick inspection
print("🔹 X_train shape:", X_train.shape)
print("🔹 X_test shape:", X_test.shape)
# Out:
# 🔹 X_train shape: (12553, 29)
# 🔹 X_test shape: (3139, 29)

# %%
print("\n🔹 Train features:")
X_train.head(3)
# Out:
# 🔹 Train features:
#      fuel_type  cylinders gear_box_type drive_wheels       wheel  color  \
# 2062    petrol          4     tiptronic          4x4  left-wheel  black
# 3729    petrol          4     automatic        front  left-wheel  black
# 1111    petrol          8     automatic          4x4  left-wheel  black
#
#       turbo  doors_count doors_cat cylinder_group  ...  doors_domain  \
# 2062   True            4       4-5            3-4  ...      4_family
# 3729  False            4       4-5            3-4  ...      4_family
# 1111  False            4       4-5            5-8  ...     4_utility
#
#      mileage_capped  engine_volume_capped  levy_capped  mileage_log  \
# 2062       181155.0                   2.0       707.00    12.107114
# 3729        31000.0                   1.5       595.00    10.341775
# 1111       264339.0                   4.7      2056.44    12.484991
#
#       engine_volume_log  levy_log manufacturer_grouped  model_median_price  \
# 2062           1.098612  6.562444                other             19130.0
# 3729           0.916291  6.390241               toyota             14113.0
# 1111           1.740466  7.629218                other             26500.0
#
#      is_top_luxury_model
# 2062                   0
# 3729                   0
# 1111                   0
#
# [3 rows x 29 columns]

# %%
print("🔹 Dataset info:\n")
X_train.info()
# Out:
# 🔹 Dataset info:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 12553 entries, 2062 to 3447
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fuel_type             12553 non-null  object
#  1   cylinders             12553 non-null  int64
#  2   gear_box_type         12553 non-null  object
#  3   drive_wheels          12553 non-null  object
#  4   wheel                 12553 non-null  object
#  5   color                 12553 non-null  object
#  6   turbo                 12553 non-null  bool
#  7   doors_count           12553 non-null  int64
#  8   doors_cat             12553 non-null  object
#  9   cylinder_group        12553 non-null  object
#  10  cylinder_group_ord    12553 non-null  int64
#  11  airbags_group         12553 non-null  object
#  12  airbags_group_ord     12553 non-null  int64
#  13  car_age               12553 non-null  int64
#  14  has_leather           12553 non-null  int64
#  15  is_common_color       12553 non-null  int64
#  16  domain                12553 non-null  object
#  17  category_simple       12553 non-null  object
#  18  engine_turbo          12553 non-null  float64
#  19  doors_domain          12553 non-null  object
#  20  mileage_capped        12553 non-null  float64
#  21  engine_volume_capped  12553 non-null  float64
#  22  levy_capped           12553 non-null  float64
#  23  mileage_log           12553 non-null  float64
#  24  engine_volume_log     12553 non-null  float64
#  25  levy_log              12553 non-null  float64
#  26  manufacturer_grouped  12553 non-null  object
#  27  model_median_price    12553 non-null  float64
#  28  is_top_luxury_model   12553 non-null  int64
# dtypes: bool(1), float64(8), int64(8), object(12)
# memory usage: 2.8+ MB

# %% [markdown]
# 💡 **Observations:**
# - Overall, the dataset looks consistent and ready for pipeline preprocessing and model training.

# %% [markdown]
# # **Preprocessing Pipelines**

# %% [markdown]
# ## Auto-detect numeric and categorical columns

# %%
# We treat booleans and numeric dtypes as numeric; object/category as categorical.
numeric_cols = X_train.select_dtypes(include=[np.number, 'bool']).columns.tolist()
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns.tolist()

# Some columns we explicitly want to ensure are numeric.
# e.g., 'is_top_luxury_model' may be int; verify it's in numeric_cols.
for col in ['model_median_price', 'is_top_luxury_model']:
    if col in X_train.columns and col not in numeric_cols:
        numeric_cols.append(col)
        if col in categorical_cols: 
            categorical_cols.remove(col)

# Remove any accidental target-like names from features (safety)
for t in ['price', 'price_capped', 'price_log']:
    if t in numeric_cols: numeric_cols.remove(t)
    if t in categorical_cols: categorical_cols.remove(t)

print("🔹 Detected numeric columns:", numeric_cols)
print("\n🔹 Detected categorical columns (sample):", categorical_cols[:10], "... (total {})".format(len(categorical_cols)))
# Out:
# 🔹 Detected numeric columns: ['cylinders', 'turbo', 'doors_count', 'cylinder_group_ord', 'airbags_group_ord', 'car_age', 'has_leather', 'is_common_color', 'engine_turbo', 'mileage_capped', 'engine_volume_capped', 'levy_capped', 'mileage_log', 'engine_volume_log', 'levy_log', 'model_median_price', 'is_top_luxury_model']
#
# 🔹 Detected categorical columns (sample): ['fuel_type', 'gear_box_type', 'drive_wheels', 'wheel', 'color', 'doors_cat', 'cylinder_group', 'airbags_group', 'domain', 'category_simple'] ... (total 12)

# %% [markdown]
# ## Build preprocessors

# %%
#  Scaled preprocessor for scale-sensitive models (impute->scale, one-hot)
#  Tree preprocessor for tree-based models (impute->ordinal) — faster and compact

# numeric pipeline used by both
numeric_imputer = SimpleImputer(strategy='median')

preprocessor_scaled = ColumnTransformer(transformers=[
    ('num', Pipeline([('imputer', numeric_imputer), ('scaler', StandardScaler())]), numeric_cols),
    ('cat', Pipeline([('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                      ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))]), categorical_cols)
], remainder='drop')  # drop anything else

preprocessor_tree = ColumnTransformer(transformers=[
    ('num', Pipeline([('imputer', numeric_imputer)]), numeric_cols),
    ('cat', Pipeline([('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                      ('ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))]), categorical_cols)
], remainder='drop')

print("✅ Preprocessors created")
# Out:
# ✅ Preprocessors created

# %% [markdown]
# # **Model construction and Training**

# %% [markdown]
# ## Define model constructors

# %%
def get_scale_sensitive_models():
    # These use y_log and require scaling
    return [
        ('LR', LinearRegression()),
        ('Ridge', Ridge()),
        ('Lasso', Lasso()),
        ('KNN', KNeighborsRegressor()),
        ('SVR', SVR())
    ]

def get_tree_models():
    # These use y_cap and do not require scaling
    return [
        ('RF', RandomForestRegressor(random_state=42, n_jobs=-1)),
        ('GBM', GradientBoostingRegressor(random_state=42))
    ]

print("✅ Model lists ready")
# Out:
# ✅ Model lists ready

# %% [markdown]
# ## CV evaluation function

# %%
def cross_validate_models(X, y, models, preprocessor, cv_folds=5, scoring='neg_root_mean_squared_error'):
    """
    Evaluate list of (name, model) using a pipeline that applies `preprocessor`.
    Returns a summary DataFrame and raw cv results dict.
    """
    results = {}
    summary_rows = []
    kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

    for name, model in models:
        pipeline = Pipeline([('preprocessor', preprocessor), ('model', model)])
        # cross_val_score returns negative RMSE if scoring is 'neg_root_mean_squared_error'
        cv_scores = cross_val_score(pipeline, X, y, cv=kf, scoring=scoring, n_jobs=-1)
        mean_rmse = -cv_scores.mean()
        std_rmse  = cv_scores.std()
        results[name] = cv_scores
        summary_rows.append({'model': name, 'mean_rmse': mean_rmse, 'std_rmse': std_rmse})
        print(f"{name}: Mean RMSE = {mean_rmse:.4f}, Std = {std_rmse:.4f}")

    summary_df = pd.DataFrame(summary_rows).sort_values('mean_rmse').reset_index(drop=True)
    return summary_df, results

# %% [markdown]
# ## Run CV for baseline models

# %%
print("=== Scale-sensitive models (use y_log) ===")
scale_models = get_scale_sensitive_models()
summary_scale, results_scale = cross_validate_models(X_train, y_train_log, scale_models, preprocessor_scaled, cv_folds=5)

print("\n=== Tree-based models (use y_cap) ===")
tree_models = get_tree_models()
summary_tree, results_tree = cross_validate_models(X_train, y_train_cap, tree_models, preprocessor_tree, cv_folds=5)

print("\n--- Summary (scale-sensitive) ---")
display(summary_scale)
print("\n--- Summary (tree-based) ---")
display(summary_tree)
# Out:
# === Scale-sensitive models (use y_log) ===
# LR: Mean RMSE = 1.1627, Std = 0.0273
# Ridge: Mean RMSE = 1.1627, Std = 0.0273
# Lasso: Mean RMSE = 1.4176, Std = 0.0239
# KNN: Mean RMSE = 1.1073, Std = 0.0218
# SVR: Mean RMSE = 1.0727, Std = 0.0400
#
# === Tree-based models (use y_cap) ===
# RF: Mean RMSE = 8019.8294, Std = 127.6733
# GBM: Mean RMSE = 9152.1884, Std = 112.9927
#
# --- Summary (scale-sensitive) ---
#    model  mean_rmse  std_rmse
# 0    SVR   1.072684  0.040040
# 1    KNN   1.107262  0.021772
# 2  Ridge   1.162710  0.027331
# 3     LR   1.162743  0.027331
# 4  Lasso   1.417560  0.023920
# --- Summary (tree-based) ---
#   model    mean_rmse    std_rmse
# 0    RF  8019.829439  127.673328
# 1   GBM  9152.188386  112.992730

# %% [markdown]
# 💡 **Observations: Within-Group Performances:**
# - Scale-sensitive models (log scale):
#     - SVR: 1.0727 - Best performance but highest variance
#
# - Tree-based models (capped scale):
#     - RF: 8,019 - Outperforms GBM, more stable (±127)

# %% [markdown]
# ## Choose top models for final test eval

# %%
# Pick top scale-sensitive and top tree-based from CV results
best_scale_name = summary_scale.iloc[0]['model']
best_tree_name  = summary_tree.iloc[0]['model']
print(f"Top scale-sensitive: {best_scale_name}, top tree-based: {best_tree_name}")

# Map names to actual model instances
scale_dict = dict(scale_models)
tree_dict  = dict(tree_models)

best_scale_model = scale_dict[best_scale_name]
best_tree_model  = tree_dict[best_tree_name]
# Out:
# Top scale-sensitive: SVR, top tree-based: RF

# %% [markdown]
# ## Fit best models on FULL train and evaluate on test

# %%
def fit_and_evaluate_on_test(X_train, y_train, X_test, y_test, preprocessor, model, target_is_log=False):
    """
    Fit pipeline on train (preprocessor+model), predict on test and compute metrics.
    If target_is_log==True: y_train and y_test are log-transformed; invert predictions before computing metrics.
    Returns pipeline, metrics dict, y_pred_original, y_test_original
    """
    pipeline = Pipeline([('preprocessor', preprocessor), ('model', model)])
    pipeline.fit(X_train, y_train)
    y_pred_raw = pipeline.predict(X_test)

    if target_is_log:
        # y_train/y_test were log1p; invert with expm1 for interpretation
        y_pred = np.expm1(y_pred_raw)
        y_true = np.expm1(y_test)
    else:
        y_pred = y_pred_raw
        y_true = y_test

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)

    metrics = {'RMSE': rmse, 'MAE': mae, 'R2': r2}
    return pipeline, metrics, y_pred, y_true

# %% [markdown]
# ## Evaluate best models best on test

# %%
pipeline_scale_best, metrics_scale, ypred_scale, ytrue_scale = fit_and_evaluate_on_test(
    X_train, y_train_log, X_test, y_test_log, preprocessor_scaled, best_scale_model, target_is_log=True
)

print("\n🔹 Best scale-sensitive model test metrics (in original price units):\n")
print(metrics_scale)

pipeline_tree_best, metrics_tree, ypred_tree, ytrue_tree = fit_and_evaluate_on_test(
    X_train, y_train_cap, X_test, y_test_cap, preprocessor_tree, best_tree_model, target_is_log=False
)

print("\n🔹 Best tree-based model test metrics (capped price units):\n")
print(metrics_tree)
# Out:
# Best scale-sensitive model test metrics (in original price units):
# {'RMSE': np.float64(9381.76666538761), 'MAE': 5396.646927966022, 'R2': 0.6744667543569305}
#
# Best tree-based model test metrics (capped price units):
# {'RMSE': np.float64(8817.138566943031), 'MAE': 5146.695778162719, 'R2': 0.7124711511494108}

# %% [markdown]
# ### 💡 **Model Performance Analysis**
#
# 🔹 Test Results Comparison
# - Scale-sensitive model (converted to original price units):
#     - RMSE: 9,382
#     - MAE: 5,397
#     - R²: 0.6745
#
# - Tree-based model (capped price units):
#     - RMSE: 8,817
#     - MAE: 5,147
#     - R²: 0.7125
# - **Key Observations**
#     - Tree-Based Model Wins Across All Metrics
#         - 6% better RMSE (8,817 vs 9,382)
#         - 5% better MAE (5,147 vs 5,397)
#         - Higher R² (0.7125 vs 0.6745) - explains ~3.8% more variance.
# > *🧠 Tree-based approach is superior for this dataset*

# %% [markdown]
# ## Simple plots: predicted vs actual for both best models

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(ytrue_scale, ypred_scale, alpha=0.4, s=10)
plt.xlabel("Actual price (original units)")
plt.ylabel("Predicted price (original units)")
plt.title(f"Pred vs Actual — {best_scale_name} (log-target -> inverted)")
lims = [min(ytrue_scale.min(), ypred_scale.min()), max(ytrue_scale.max(), ypred_scale.max())]
plt.plot(lims, lims, '--', color='gray')

plt.subplot(1,2,2)
plt.scatter(ytrue_tree, ypred_tree, alpha=0.4, s=10)
plt.xlabel("Actual price (capped)")
plt.ylabel("Predicted price (capped)")
plt.title(f"Pred vs Actual — {best_tree_name} (capped-target)")
lims2 = [min(ytrue_tree.min(), ypred_tree.min()), max(ytrue_tree.max(), ypred_tree.max())]
plt.plot(lims2, lims2, '--', color='gray')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save best pipelines

# %%
OUT_DIR = "models"
joblib.dump(pipeline_scale_best, os.path.join(OUT_DIR, f"best_pipeline_{best_scale_name}.pkl"))
joblib.dump(pipeline_tree_best, os.path.join(OUT_DIR, f"best_pipeline_{best_tree_name}.pkl"))
print(f"Saved best pipelines: best_pipeline_{best_scale_name}.pkl and best_pipeline_{best_tree_name}.pkl")
# Out:
# Saved best pipelines: best_pipeline_SVR.pkl and best_pipeline_RF.pkl

# %% [markdown]
# # **Diagnostics + Interpretability**

# %% [markdown]
# ## Load back the saved pipelines

# %%
# Load best models
scale_model = joblib.load(os.path.join(OUT_DIR, f"best_pipeline_{best_scale_name}.pkl"))
tree_model  = joblib.load(os.path.join(OUT_DIR, f"best_pipeline_{best_tree_name}.pkl"))

# %% [markdown]
# ## Residual analysis (check heteroscedasticity)

# %%
# Get predictions (assuming X_test, y_test are defined)
y_pred_tree  = tree_model.predict(X_test)
residuals = y_test_cap - y_pred_tree

# Side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Residuals vs Predicted
sns.scatterplot(x=y_pred_tree, y=residuals, alpha=0.6, ax=axes[0])
axes[0].axhline(0, color="red", linestyle="--")
axes[0].set_xlabel("Predicted Price")
axes[0].set_ylabel("Residuals (Actual - Predicted)")
axes[0].set_title("Residuals vs Predicted (Tree Model)")

# Histogram of residuals
sns.histplot(residuals, kde=True, bins=30, ax=axes[1])
axes[1].axvline(0, color="red", linestyle="--")
axes[1].set_xlabel("Residuals")
axes[1].set_title("Distribution of Residuals")

plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 **Observations:**
# - Residuals vs Predicted (heteroscedasticity):
#     - Clear heteroscedasticity: Errors grow as predicted price increases → the model struggles more with expensive cars.
#     - Systematic bias: Positive residuals at the high end = underestimation of high-value cars.
#     - Non-random scatter: Means model assumptions of constant variance are violated.
# - Residual distribution (histogram):
#     - Centered near zero: Good sign → no huge global bias.
#     - Sharp peak around zero: Most predictions are decent, but there are notable misses on expensive cases.
# > 🧩 Log-transform target

# %% [markdown]
# ## Train tree model on log target

# %%
pipeline_tree_log = Pipeline([
    ("preprocessor", preprocessor_tree),
    ("regressor", RandomForestRegressor(n_estimators=300, random_state=42))
    ])

pipeline_tree_log.fit(X_train, y_train_log)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['cylinders', 'turbo',
#                                                    'doors_count',
#                                                    'cylinder_group_ord',
#                                                    'airbags_group_ord',
#                                                    'car_age', 'has_leather',
#                                                    'is_common_color',
#                                                    'engine_turbo',
#                                                    'mileage_capped',
#                                                    'engine_volume_capped',
#                                                    'levy_capped', 'mileage_log',
#                                                    'engine_volume_...
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['fuel_type', 'gear_box_type',
#                                                    'drive_wheels', 'wheel',
#                                                    'color', 'doors_cat',
#                                                    'cylinder_group',
#                                                    'airbags_group', 'domain',
#                                                    'category_simple',
#                                                    'doors_domain',
#                                                    'manufacturer_grouped'])])),
#                 ('regressor',
#                  RandomForestRegressor(n_estimators=300, random_state=42))])

# %%
# Predictions back to real price scale: Predictions (log-space → real)
y_pred_log = pipeline_tree_log.predict(X_test)
y_pred_real = np.expm1(y_pred_log)      # back-transform
y_test_real = np.expm1(y_test_log)      # original capped values

# %%
# Evaluate metrics
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred_real))
mae = mean_absolute_error(y_test_real, y_pred_real)
r2  = r2_score(y_test_real, y_pred_real)

print("📊 Tree Model (log target, back-transformed):")
print(f"RMSE: {rmse:,.0f}")
print(f"MAE : {mae:,.0f}")
print(f"R²  : {r2:.2f}")
# Out:
# 📊 Tree Model (log target, back-transformed):
# RMSE: 11,582
# MAE : 6,917
# R²  : 0.50

# %% [markdown]
# ## Feature Importane Analysis

# %% [markdown]
# ### function declaration

# %%
def analyze_feature_importance(model, feature_names, top_n=20):    
    # Get feature importance
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
    elif hasattr(model, 'coef_'):
        importances = np.abs(model.coef_)
    else:
        print("Model doesn't have feature_importances_ or coef_ attribute")
        return None
    
    # Create DataFrame
    feature_imp_df = pd.DataFrame({
        'feature': feature_names,
        'importance': importances
    }).sort_values('importance', ascending=False)
    
    # Top features
    top_features = feature_imp_df.head(top_n)
    
    # Visualization
    fig, axes = plt.subplots(2, 2, figsize=(20, 15))
    
    # Bar plot of top features
    top_features.plot(x='feature', y='importance', kind='barh', ax=axes[0,0])
    axes[0,0].set_title(f'Top {top_n} Feature Importances')
    axes[0,0].set_xlabel('Importance')
    
    # Cumulative importance
    feature_imp_df['cumulative_importance'] = feature_imp_df['importance'].cumsum()
    feature_imp_df['cumulative_importance_pct'] = (feature_imp_df['cumulative_importance'] / 
                                                  feature_imp_df['importance'].sum() * 100)
    
    axes[0,1].plot(range(len(feature_imp_df)), feature_imp_df['cumulative_importance_pct'])
    axes[0,1].set_title('Cumulative Feature Importance')
    axes[0,1].set_xlabel('Number of Features')
    axes[0,1].set_ylabel('Cumulative Importance (%)')
    axes[0,1].grid(True)
    
    # Add line at 80% and 95%
    axes[0,1].axhline(y=80, color='r', linestyle='--', label='80%')
    axes[0,1].axhline(y=95, color='orange', linestyle='--', label='95%')
    axes[0,1].legend()
    
    # Importance distribution
    axes[1,0].hist(feature_imp_df['importance'], bins=50, alpha=0.7)
    axes[1,0].set_title('Distribution of Feature Importances')
    axes[1,0].set_xlabel('Importance')
    axes[1,0].set_ylabel('Frequency')
    
    # Top 10 vs rest
    top_10_sum = feature_imp_df.head(10)['importance'].sum()
    rest_sum = feature_imp_df.tail(-10)['importance'].sum()
    
    axes[1,1].pie([top_10_sum, rest_sum], 
                  labels=['Top 10 Features', 'Remaining Features'],
                  autopct='%1.1f%%')
    axes[1,1].set_title('Importance Distribution: Top 10 vs Rest')
    
    plt.tight_layout()
    plt.show()
    
    # Print insights
    features_80_pct = len(feature_imp_df[feature_imp_df['cumulative_importance_pct'] <= 80])
    features_95_pct = len(feature_imp_df[feature_imp_df['cumulative_importance_pct'] <= 95])
    
    print("🍀 FEATURE IMPORTANCE INSIGHTS 🍀 ")
    print(f"🔹 Total features: {len(feature_names)}")
    print(f"🔹 Features needed for 80% importance: {features_80_pct}")
    print(f"🔹 Features needed for 95% importance: {features_95_pct}")
    print(f"🔹 Top feature importance: {feature_imp_df.iloc[0]['importance']:.4f}")
    print(f"🔹 Median feature importance: {feature_imp_df['importance'].median():.4f}")
    
    print(f"\n🍀 Top {min(10, len(top_features))} Most Important Features:")
    for i, row in top_features.head(10).iterrows():
        print(f"🔹 {row['feature']}: {row['importance']:.4f}")
    
    return feature_imp_df

# %% [markdown]
# ### Apply function

# %%
# Extract final tree model
final_tree = tree_model.named_steps["model"]

# Feature names from preprocessor
numeric_features = numeric_cols
categorical_features = categorical_cols
feature_names = numeric_features + categorical_features  # adjust if OrdinalEncoder expands them

# Run feature importance analysis
feature_importance_df = analyze_feature_importance(final_tree, feature_names, top_n=20)
# Out:
# 🍀 FEATURE IMPORTANCE INSIGHTS 🍀
# 🔹 Total features: 29
# 🔹 Features needed for 80% importance: 7
# 🔹 Features needed for 95% importance: 15
# 🔹 Top feature importance: 0.4223
# 🔹 Median feature importance: 0.0134
#
# 🍀 Top 10 Most Important Features:
# 🔹 model_median_price: 0.4223
# 🔹 car_age: 0.1629
# 🔹 engine_turbo: 0.0453
# 🔹 mileage_capped: 0.0400
# 🔹 gear_box_type: 0.0394
# 🔹 mileage_log: 0.0390
# 🔹 airbags_group_ord: 0.0264
# 🔹 airbags_group: 0.0250
# 🔹 levy_capped: 0.0250
# 🔹 levy_log: 0.0247

# %% [markdown]
# ### Select top 15 features

# %%
# Top 15 features from feature_importance_df
top_features = feature_importance_df.head(15)['feature'].tolist()
print("Top 15 features:", top_features)
# Out:
# Top 15 features: ['model_median_price', 'car_age', 'engine_turbo', 'mileage_capped', 'gear_box_type', 'mileage_log', 'airbags_group_ord', 'airbags_group', 'levy_capped', 'levy_log', 'engine_volume_capped', 'engine_volume_log', 'manufacturer_grouped', 'color', 'fuel_type']

# %%
# Subset X for top features
X_train_top = X_train[top_features]

# %%
top_categorical = [f for f in top_features if f in categorical_cols]

# %%
# Determine which top features are numeric vs categorical
top_numeric = [f for f in top_features if f in numeric_cols]
top_categorical = [f for f in top_features if f in categorical_cols]

# Preprocessor for top features
preprocessor_top = ColumnTransformer(transformers=[
    ('num', Pipeline([('imputer', SimpleImputer(strategy='median'))]), top_numeric),
    ('cat', Pipeline([('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                      ('ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))]), top_categorical)
], remainder='drop')

# Pipeline
pipeline_tree_top = Pipeline([
    ('preprocessor', preprocessor_top),
    ('model', RandomForestRegressor(n_estimators=300, random_state=42))
])

# Train
pipeline_tree_top.fit(X_train_top, y_train_cap)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['model_median_price',
#                                                    'car_age', 'engine_turbo',
#                                                    'mileage_capped',
#                                                    'mileage_log',
#                                                    'airbags_group_ord',
#                                                    'levy_capped', 'levy_log',
#                                                    'engine_volume_capped',
#                                                    'engine_volume_log']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['gear_box_type',
#                                                    'airbags_group',
#                                                    'manufacturer_grouped',
#                                                    'color', 'fuel_type'])])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=300, random_state=42))])

# %%
# Predict
y_pred_top = pipeline_tree_top.predict(X_test)

# Metrics
rmse = np.sqrt(mean_squared_error(y_test_cap, y_pred_top))
mae = mean_absolute_error(y_test_cap, y_pred_top)
r2 = r2_score(y_test_cap, y_pred_top)

print("📊 Tree Model (Top 15 Features):")
print(f"RMSE: {rmse:,.0f}")
print(f"MAE : {mae:,.0f}")
print(f"R²  : {r2:.2f}")
# Out:
# 📊 Tree Model (Top 15 Features):
# RMSE: 9,021
# MAE : 5,320
# R²  : 0.70

# %%
residuals_top = y_test_cap - y_pred_top

plt.figure(figsize=(7,5))
sns.scatterplot(x=y_pred_top, y=residuals_top, alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted (Tree Model, Top 15 Features)")
plt.show()

# %% [markdown]
# 💡 **Observations:**
# - Slight increase in RMSE & MAE - Losing ~200 in RMSE and ~170 in MAE is very minor.
# - The top 15 features capture almost all predictive power.
# - R² only drops from 0.71 → 0.70 : Negligible reduction — the model still explains ~70% of variance.
# - Residuals: Scatter plots look very similar to the full model.
# > *🧠 Using only the top 15 features is a safe simplification:*

# %% [markdown]
# # **Hyperparameter tuning**

# %%
param_grid = {
    'model__n_estimators': [200, 300, 500, 700],
    'model__max_depth': [10, 15, 20, 25, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2', 0.5, None]
}

# Randomized search
search = RandomizedSearchCV(
    pipeline_tree_best,      # pipeline with top 15 features
    param_distributions=param_grid,
    n_iter=30,              # number of random combinations
    scoring='neg_root_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

search.fit(X_train, y_train_cap)
print("🍀  Best params:", search.best_params_)
print("🍀 Best RMSE:", -search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best params: {'model__n_estimators': 700, 'model__min_samples_split': 5, 'model__min_samples_leaf': 1, 'model__max_features': 0.5, 'model__max_depth': 20}
# Best RMSE: 7987.615623069755
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   6.7s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time=  35.2s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  15.6s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  19.7s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  16.6s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300; total time=  10.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=   7.9s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=700; total time=  19.8s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=700; total time=  24.3s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=  13.0s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   9.7s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  37.4s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=  13.3s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=  13.8s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   9.8s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=700; total time=  22.1s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=  16.0s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=  18.3s
# [CV] END model__max_depth=20, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   7.3s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  37.7s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  25.8s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=700; total time=  25.0s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time= 1.7min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   7.7s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   9.3s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  19.1s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  18.0s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time=  56.8s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   8.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   8.1s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.7min
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.4min
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.1min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  14.7s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  13.8s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=  17.8s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=  26.9s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   6.6s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   6.7s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time=  33.9s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  18.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  19.4s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  14.8s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300; total time=   9.4s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=   8.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=700; total time=  17.9s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=  19.7s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=  14.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   9.5s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  39.1s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500; total time= 1.4min
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=  12.1s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=  13.2s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=700; total time=  20.7s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=700; total time=  18.2s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=  14.7s
# [CV] END model__max_depth=20, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=20, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=500; total time= 1.1min
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=700; total time=  26.8s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time= 1.7min
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time= 1.4min
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time=  55.6s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.7min
# [CV] END model__max_depth=25, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=500; total time=  17.4s
# [CV] END model__max_depth=25, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=500; total time=  17.0s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=700; total time=  22.2s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=700; total time=  24.0s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.2min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  15.1s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=  18.0s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=  17.9s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=  25.4s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   6.7s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time=  34.2s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  16.4s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  19.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  16.0s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300; total time=  10.2s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=   7.1s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=   7.8s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=700; total time=  18.1s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=  19.6s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=  12.2s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=  10.1s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  37.1s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=  16.8s
# [CV] END model__max_depth=20, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   8.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   7.8s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  37.3s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  24.8s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=700; total time=  25.6s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time= 1.7min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   8.6s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   8.4s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  18.5s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time=  56.6s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time=  52.0s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.7min
# [CV] END model__max_depth=25, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=500; total time=  17.5s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=700; total time=  20.7s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=700; total time=  23.1s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.2min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  14.8s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  14.0s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=  18.7s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=  18.0s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=  21.4s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   6.6s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time=  32.9s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time=  30.3s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=500; total time=  18.9s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300; total time=  10.4s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=300; total time=  10.2s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=   8.1s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=700; total time=  17.9s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=  19.2s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=  15.3s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  35.9s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=500; total time=  38.2s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=500; total time= 1.5min
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=700; total time=  22.5s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=700; total time=  17.4s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=4, model__min_samples_split=5, model__n_estimators=300; total time=  16.8s
# [CV] END model__max_depth=20, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   8.6s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   8.1s
# [CV] END model__max_depth=10, model__max_features=0.5, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  36.5s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=700; total time=  25.2s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=700; total time=  24.7s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time= 1.7min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   9.0s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  19.4s
# [CV] END model__max_depth=25, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=500; total time=  19.0s
# [CV] END model__max_depth=20, model__max_features=0.5, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=700; total time=  56.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   7.5s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   8.6s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=300; total time=   7.6s
# [CV] END model__max_depth=None, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.8min
# [CV] END model__max_depth=25, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=500; total time=  16.4s
# [CV] END model__max_depth=25, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=10, model__n_estimators=500; total time=  16.1s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=700; total time=  23.3s
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.2min
# [CV] END model__max_depth=15, model__max_features=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=500; total time= 1.1min
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=  27.0s
# [CV] END model__max_depth=10, model__max_features=None, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=  13.6s

# %%
y_pred_tuned = search.best_estimator_.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test_cap, y_pred_tuned))
mae = mean_absolute_error(y_test_cap, y_pred_tuned)
r2 = r2_score(y_test_cap, y_pred_tuned)

print("🍀  Tuned Tree Model:")
print(f"RMSE: {rmse:,.0f}")
print(f"MAE : {mae:,.0f}")
print(f"R²  : {r2:.2f}")
# Out:
# 🍀  Tuned Tree Model:
# RMSE: 8,777
# MAE : 5,130
# R²  : 0.72

# %% [markdown]
# 💡 **Observations:**
# - RMSE improvement: ~40 units better than full model.
#
# - MAE improvement: ~17 units better — small but meaningful.
#
# - R² increase: 0.71 → 0.72, showing slightly more variance explained.
#
# > **🍀 Our model now explains ~72% of the variance in car prices.**

# %% [markdown]
# # **Segmented modeling**

# %% [markdown]
# ### Define luxury threshold on training target

# %%
luxury_threshold = y_train_cap.quantile(0.95)

# %% [markdown]
# ### Create masks for training data

# %%
luxury_mask_train = y_train_cap >= luxury_threshold
regular_mask_train = ~luxury_mask_train

# %% [markdown]
# ### Split training data

# %%
X_train_luxury = X_train[luxury_mask_train]
y_train_luxury = y_train_cap[luxury_mask_train]

X_train_regular = X_train[regular_mask_train]
y_train_regular = y_train_cap[regular_mask_train]

# %% [markdown]
# ### Train separate pipelines

# %%
pipeline_regular = Pipeline([
    ('preprocessor', preprocessor_tree),
    ('regressor', RandomForestRegressor(n_estimators=300, random_state=42))
])
pipeline_regular.fit(X_train_regular, y_train_regular)

pipeline_luxury = Pipeline([
    ('preprocessor', preprocessor_tree),
    ('regressor', RandomForestRegressor(n_estimators=300, random_state=42))
])
pipeline_luxury.fit(X_train_luxury, y_train_luxury)
print("✅ Model trained")
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['cylinders', 'turbo',
#                                                    'doors_count',
#                                                    'cylinder_group_ord',
#                                                    'airbags_group_ord',
#                                                    'car_age', 'has_leather',
#                                                    'is_common_color',
#                                                    'engine_turbo',
#                                                    'mileage_capped',
#                                                    'engine_volume_capped',
#                                                    'levy_capped', 'mileage_log',
#                                                    'engine_volume_...
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['fuel_type', 'gear_box_type',
#                                                    'drive_wheels', 'wheel',
#                                                    'color', 'doors_cat',
#                                                    'cylinder_group',
#                                                    'airbags_group', 'domain',
#                                                    'category_simple',
#                                                    'doors_domain',
#                                                    'manufacturer_grouped'])])),
#                 ('regressor',
#                  RandomForestRegressor(n_estimators=300, random_state=42))])

# %% [markdown]
# ### Create masks for test data

# %%
luxury_mask_test = X_test['model_median_price'] >= luxury_threshold
regular_mask_test = ~luxury_mask_test

# %% [markdown]
# ### Make predictions on test set

# %%
y_pred_combined = np.zeros(X_test.shape[0])

y_pred_combined[luxury_mask_test] = pipeline_luxury.predict(X_test[luxury_mask_test])
y_pred_combined[regular_mask_test] = pipeline_regular.predict(X_test[regular_mask_test])

# %% [markdown]
# ### Evaluate metrics

# %%
rmse = np.sqrt(mean_squared_error(y_test_cap, y_pred_combined))
mae  = mean_absolute_error(y_test_cap, y_pred_combined)
r2   = r2_score(y_test_cap, y_pred_combined)

print("🍀 Segmented Tree Model (Regular + Luxury):")
print(f"RMSE: {rmse:,.0f}")
print(f"MAE : {mae:,.0f}")
print(f"R²  : {r2:.2f}")
# Out:
# 🍀 Segmented Tree Model (Regular + Luxury):
# RMSE: 11,342
# MAE : 6,193
# R²  : 0.52

# %% [markdown]
# 💡 **Observations:**
# - the metrics show the segmented model underperforms the tuned single-tree model
